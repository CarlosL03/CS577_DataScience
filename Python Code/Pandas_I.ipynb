# %% [markdown]
# Carlos Lopez
#
# CS-577: Pandas Homework 1

# %%
import pandas as pd

# %%
#Slide 26
elections = pd.read_csv("/content/elections.csv", index_col = "Candidate")
elections.head()
# Out:
#                    Year        Party  Popular vote Result      %
# Candidate
# George Washington  1788  Independent           NaN    win  100.0
# John Adams         1788   Federalist           NaN   loss    NaN
# George Washington  1792  Independent           NaN    win  100.0
# John Adams         1792   Federalist           NaN   loss    NaN
# John Adams         1796   Federalist           NaN    win   53.4

# %%
#Slide 28
elections.set_index("Party")
# Out:
#              Year  Popular vote Result           %
# Party
# Independent  1788           NaN    win  100.000000
# Federalist   1788           NaN   loss         NaN
# Independent  1792           NaN    win  100.000000
# Federalist   1792           NaN   loss         NaN
# Federalist   1796           NaN    win   53.400000
# ...           ...           ...    ...         ...
# Green        2020      405035.0   loss    0.255731
# Democratic   2020    81268924.0    win   51.311515
# Libertarian  2020     1865724.0   loss    1.177979
# Republican   2024    77300000.0    win   49.800000
# Democratic   2024    75000000.0   loss   48.300000
#
# [74 rows x 4 columns]

# %%
#Slide 29
elections.reset_index()
# Out:
#             Candidate  Year        Party  Popular vote Result           %
# 0   George Washington  1788  Independent           NaN    win  100.000000
# 1          John Adams  1788   Federalist           NaN   loss         NaN
# 2   George Washington  1792  Independent           NaN    win  100.000000
# 3          John Adams  1792   Federalist           NaN   loss         NaN
# 4          John Adams  1796   Federalist           NaN    win   53.400000
# ..                ...   ...          ...           ...    ...         ...
# 69     Howard Hawkins  2020        Green      405035.0   loss    0.255731
# 70       Joseph Biden  2020   Democratic    81268924.0    win   51.311515
# 71       Jo Jorgensen  2020  Libertarian     1865724.0   loss    1.177979
# 72       Donald Trump  2024   Republican    77300000.0    win   49.800000
# 73      Kamala Harris  2024   Democratic    75000000.0   loss   48.300000
#
# [74 rows x 6 columns]

# %%
#Slide 31
elections.set_index("Party")
print(elections.index, end="\n\n")
print(elections.columns, end="\n\n")
print(elections.shape, end="\n\n")
# Out:
# Index(['George Washington', 'John Adams', 'George Washington', 'John Adams',
#        'John Adams', 'Thomas Jefferson', 'Thomas Jefferson', 'John Adams',
#        'Thomas Jefferson', 'Charles C. Pinckney', 'James Madison',
#        'Charles C. Pinckney', 'James Madison', 'DeWitt Clinton',
#        'James Monroe', 'Rufus King', 'James Monroe', 'John Quincy Adams',
#        'Andrew Jackson', 'John Quincy Adams', 'Andrew Jackson',
#        'John Quincy Adams', 'Andrew Jackson', 'William Henry Harrison',
#        'Martin Van Buren', 'Martin Van Buren', 'William Henry Harrison',
#        'James K. Polk', 'Henry Clay', 'Zachary Taylor', 'Lewis Cass',
#        'Franklin Pierce', 'Winfield Scott', 'John C. Frémont',
#        'James Buchanan', 'John C. Breckinridge', 'Abraham Lincoln',
#        'Abraham Lincoln', 'George B. McClellan', 'Horatio Seymour',
#        'Ulysses S. Grant', 'Ulysses S. Grant', 'Horace Greeley',
#        'Samuel J. Tilden', 'Rutherford B. Hayes', 'James A. Garfield',
# ...

# %%
#Slide 37
elections = elections.reset_index()
print(elections.head(5))
print("\n\n")
print(elections.tail(5))
# Out:
#            Candidate  Year        Party  Popular vote Result      %
# 0  George Washington  1788  Independent           NaN    win  100.0
# 1         John Adams  1788   Federalist           NaN   loss    NaN
# 2  George Washington  1792  Independent           NaN    win  100.0
# 3         John Adams  1792   Federalist           NaN   loss    NaN
# 4         John Adams  1796   Federalist           NaN    win   53.4
#
#
#
#          Candidate  Year        Party  Popular vote Result          %
# 69  Howard Hawkins  2020        Green      405035.0   loss   0.255731
# 70    Joseph Biden  2020   Democratic    81268924.0    win  51.311515
# 71    Jo Jorgensen  2020  Libertarian     1865724.0   loss   1.177979
# 72    Donald Trump  2024   Republican    77300000.0    win  49.800000
# 73   Kamala Harris  2024   Democratic    75000000.0   loss  48.300000

# %%
#Slide 40
elections.loc[[66, 25, 73], ["Year", "Candidate", "Result"]]
# Out:
#     Year          Candidate Result
# 66  1920  Warren G. Harding    win
# 25  1840   Martin Van Buren   loss
# 73  2024      Kamala Harris   loss

# %%
#Slide 41
elections.loc[[66, 25, 73], "Popular vote":"%"]
# Out:
#     Popular vote Result      %
# 66    16144093.0    win  60.32
# 25     1228925.0   loss  47.13
# 73    75000000.0   loss  48.30

# %%
#Slide 42
print(elections.loc[:, ["Year", "Candidate", "Result"]])
print("\n\n")
print(elections.loc[[66, 25, 73], :])
# Out:
#     Year          Candidate Result
# 0   1788  George Washington    win
# 1   1788         John Adams   loss
# 2   1792  George Washington    win
# 3   1792         John Adams   loss
# 4   1796         John Adams    win
# ..   ...                ...    ...
# 69  2020     Howard Hawkins   loss
# 70  2020       Joseph Biden    win
# 71  2020       Jo Jorgensen   loss
# 72  2024       Donald Trump    win
# 73  2024      Kamala Harris   loss
#
# [74 rows x 3 columns]
#
#
#
#             Candidate  Year       Party  Popular vote Result      %
# 66  Warren G. Harding  1920  Republican    16144093.0    win  60.32
# 25   Martin Van Buren  1840  Democratic     1228925.0   loss  47.13
# 73      Kamala Harris  2024  Democratic    75000000.0   loss  48.30

# %%
#Slide 43
print(elections.loc[[66, 25, 73], "Popular vote"])
print("\n\n")
print(elections.loc[0, "Candidate"])
# Out:
# 66    16144093.0
# 25     1228925.0
# 73    75000000.0
# Name: Popular vote, dtype: float64
#
#
#
# George Washington

# %%
#Slide 46
elections.iloc[[1,2,3], [0,1,2]]
# Out:
#            Candidate  Year        Party
# 1         John Adams  1788   Federalist
# 2  George Washington  1792  Independent
# 3         John Adams  1792   Federalist

# %%
#Slide 47
elections.iloc[[1,2,3], 0:3]
# Out:
#            Candidate  Year        Party
# 1         John Adams  1788   Federalist
# 2  George Washington  1792  Independent
# 3         John Adams  1792   Federalist

# %%
#Slide 48
elections.iloc[:, 0:3]
# Out:
#             Candidate  Year        Party
# 0   George Washington  1788  Independent
# 1          John Adams  1788   Federalist
# 2   George Washington  1792  Independent
# 3          John Adams  1792   Federalist
# 4          John Adams  1796   Federalist
# ..                ...   ...          ...
# 69     Howard Hawkins  2020        Green
# 70       Joseph Biden  2020   Democratic
# 71       Jo Jorgensen  2020  Libertarian
# 72       Donald Trump  2024   Republican
# 73      Kamala Harris  2024   Democratic
#
# [74 rows x 3 columns]

# %%
#Slide 49
print(elections.iloc[[1,2,3], 1])
print("\n\n")
print(elections.iloc[0, 1])
# Out:
# 1    1788
# 2    1792
# 3    1792
# Name: Year, dtype: int64
#
#
#
# 1788

# %%
#Slide 53
elections[3:7]
# Out:
#           Candidate  Year                  Party  Popular vote Result     %
# 3        John Adams  1792             Federalist           NaN   loss   NaN
# 4        John Adams  1796             Federalist           NaN    win  53.4
# 5  Thomas Jefferson  1796  Democratic-Republican           NaN   loss  46.6
# 6  Thomas Jefferson  1800  Democratic-Republican           NaN    win  61.4

# %%
#Slide 54
elections[["Year", "Candidate", "Result"]]
# Out:
#     Year          Candidate Result
# 0   1788  George Washington    win
# 1   1788         John Adams   loss
# 2   1792  George Washington    win
# 3   1792         John Adams   loss
# 4   1796         John Adams    win
# ..   ...                ...    ...
# 69  2020     Howard Hawkins   loss
# 70  2020       Joseph Biden    win
# 71  2020       Jo Jorgensen   loss
# 72  2024       Donald Trump    win
# 73  2024      Kamala Harris   loss
#
# [74 rows x 3 columns]

# %%
#Slide 55
elections["Candidate"]
# Out:
# 0     George Washington
# 1            John Adams
# 2     George Washington
# 3            John Adams
# 4            John Adams
#             ...
# 69       Howard Hawkins
# 70         Joseph Biden
# 71         Jo Jorgensen
# 72         Donald Trump
# 73        Kamala Harris
# Name: Candidate, Length: 74, dtype: object
